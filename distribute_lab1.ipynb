# %% [markdown]
# # Lab 1: Dictionaries and Classes

# %% [markdown]
# ## EXERCISE 1: Count words in Julius Caesar and make a text based histogram
#
# Building on the first lab, using lowercase words, lets make a histogram. Create a dictionary `worddict`, that has the counts of all the words in Caesar.

# %%
# your code here
import requests

def load_and_count_words_from_url(url):
    response = requests.get(url)
    response.raise_for_status()  # Ensure the request was successful
    text = response.text
    word_dict = {}
    for line in text.split('\n'):
        line = line.strip()  # Remove newline characters
        line_words = line.split()  # Split the line into words
        for word in line_words:
            lower_word = word.lower()  # Convert word to lowercase
            if lower_word in word_dict:
                word_dict[lower_word] += 1
            else:
                word_dict[lower_word] = 1
    return word_dict

def main():
    # URL to the raw text file in your GitHub repository
    url = 'https://github.com/veroaba/Labs.git'
    word_counts = load_and_count_words_from_url(url)
    sorted_words = sort_word_counts(word_counts)
    for word, count in sorted_words:
        print(f"{word}: {count}")

main()
# Out:
# 0: 2937
# 1: 772
# data-view-component="true": 205
# 1.75: 168
# <div: 138
# 16: 136
# aria-hidden="true": 130
# viewbox="0: 128
# 16": 119
# height="16": 117
# width="16": 117
# class="octicon: 116
# </div>: 108
# version="1.1": 104
# <path: 103
# <svg: 102
# </svg>: 96
# to: 91
# crossorigin="anonymous": 83
# <a: 79
# <script: 72
# 1.5: 71
# defer="defer": 68
# type="application/javascript": 68
# 2: 67
# <span: 53
# 8: 53
# class="box-sc-g0xbh4-0: 53
# 2.25: 44
# >: 39
# no-underline: 39
# position-relative: 38
# <template: 37
# </template>: 37
# <meta: 34
# d-block: 34
# </a></li>: 34
# <li>: 32
# py-2: 31
# 2.784: 31
# go: 30
# 3.75: 30
# .784: 30
# data-analytics-event="{&quot;category&quot;:&quot;header: 29
# (logged: 29
# type="button": 28
# class="headermenu-dropdown-link: 28
# lh-condensed: 28
# dropdown: 28
# out),: 28
# @media: 27
# and: 26
# <li: 25
# d-flex: 24
# flex-items-center: 24
# 1-1.5: 24
# focusable="false": 24
# fill="currentcolor": 24
# style="display:inline-block;user-select:none;vertical-align:text-bottom;overflow:visible"><path: 24
# </a>: 23
# </li>: 23
# role="img": 23
# <button: 22
# <link: 21
# />: 21
# /><meta: 21
# d="m8: 21
# 0z"></path>: 21
# 6.5: 21
# 3: 20
# 1-1.042-.018.751.751: 19
# screen: 19
# 1px: 19
# 1.06: 18
# link--secondary": 18
# 6: 18
# 3.5: 18
# [data-component="buttoncontent"]: 18
# </span>: 17
# </button>: 16
# 1.75.784: 16
# media="all": 15
# rel="stylesheet": 15
# <ul: 15
# 14.25: 15
# 9: 15
# 1.275.749.749: 15
# d="m2: 15
# .75.75: 15
# solid: 15
# class="skeleton: 15
# 0-.25.25v12.5c0: 14
# </ul>: 14
# 1-.326: 14
# 14.25zm1.75-.25a.25.25: 14
# 13.25: 14
# 0-1.5: 14
# skeleton--text">: 14
# .909.184: 13
# 1.237.513l2.914: 13
# 2.914c.329.328.513.773.513: 13
# .25-.25v6h-2.75a1.75: 13
# class="link--secondary: 13
# in: 12
# product&quot;,&quot;action&quot;:&quot;click: 12
# 9.5: 12
# 2.5: 12
# 4: 12
# mr-2">: 12
# 2.251: 12
# 1.5.75.75: 12
# 1.998: 12
# var(--fgcolor-accent,var(--color-accent-fg,#0969da));outline-offset:-2px;}/*!sc*/: 12
# :not(:last-child){margin-right:8px;}/*!sc*/: 12
# class="react-directory-filename-column"><svg: 12
# class="color-fg-muted": 12
# 1.75c2: 12
# 0h6.586c.464: 12
# 1.237v9.586a1.75: 12
# 16h-9.5a1.75: 12
# .138.112.25.25.25h9.5a.25.25: 12
# 4.25v1.5zm6.75.062v4.25c0: 12
# .138.112.25.25.25h2.688l-.011-.013-2.914-2.914-.013-.011z"></path></svg><div: 12
# class="overflow-hidden"><h3><div: 12
# class="react-directory-truncate"><a: 12
# (file)": 12
# class="link--primary": 12
# no-wrap: 11
# 1-1.06: 11
# <div>: 11
# class="color-fg-default: 11
# solutions&quot;,&quot;action&quot;:&quot;click: 11
# ": 11
# hidden="hidden": 11
# 1.042.018.751.751: 11
# .018: 11
# d="m0: 11
# class="d-flex: 10
# link--secondary: 10
# mr-3">: 10
# 1-2: 10
# 1.5h-.5a.75.75: 10
# .138.112.25.25.25h8.5a.25.25: 10
# 0-1.06z"></path>: 10
# be: 10
# d-none: 10
# signed: 10
# .fruydv: 10
# class="types__styledbutton-sc-ws60qy-0: 10
# flex-justify-between: 9
# rounded: 9
# flex-wrap: 9
# class="list-style-none: 9
# height="24": 9
# width="24": 9
# 12: 9
# target="_blank": 9
# d="m3.75: 9
# 12.25: 9
# 10: 9
# 1.784: 9
# [data-component=buttoncounter]{font-size:12px;}/*!sc*/: 9
# /><link: 8
# width-full: 8
# f5": 8
# 24: 8
# 24": 8
# color-fg-subtle: 8
# 1.748: 8
# octicon-link-external: 8
# headermenu-external-icon: 8
# color-fg-subtle">: 8
# 2h3.5a.75.75: 8
# 1.5h-3.5a.25.25: 8
# 0-.25.25v8.5c0: 8
# .25-.25v-3.5a.75.75: 8
# 0v3.5a1.75: 8
# 14h-8.5a1.75: 8
# 12.25v-8.5c2: 8
# 2zm6.854-1h4.146a.25.25: 8
# .25.25v4.146a.25.25: 8
# 1-.427.177l13.03: 8
# 4.03: 8
# 9.28: 8
# 7.78a.751.751: 8
# 1-.018-1.042l3.75-3.75-1.543-1.543a.25.25: 8
# 10.604: 8
# 1z"></path>: 8
# <input: 8
# <!--: 8
# 7: 8
# 13.5: 8
# this: 8
# data-pjax="#repo-content-pjax-container": 8
# must: 8
# assignment: 8
# committed: 8
# /: 8
# .cuowtr: 8
# .pyyxt: 8
# .gyvpxq: 8
# <h2: 7
# border-0: 7
# 1.06l-4.25: 7
# 4.25a.749.749: 7
# p-0: 7
# pb-lg-3": 7
# 0-.25.25v7.5c0: 7
# 0a.75.75: 7
# 5: 7
# color-fg-default: 7
# open: 7
# or: 7
# type="hidden": 7
# .138.112.25.25.25h12.5a.25.25: 7
# 0-3: 7
# data-turbo-frame="repo-content-turbo-frame": 7
# btn: 7
# .354: 7
# tabindex="-1": 7
# transparent;}/*!sc*/: 7
# .tdszd: 7
# .fakxqn: 7
# data-component="buttoncontent": 7
# kkrdeu"><span: 7
# -: 6
# data-turbo-transient>: 6
# on: 6
# sign: 6
# d-lg-flex: 6
# class="headermenu-link: 6
# 13: 6
# 3.25a.75.75: 6
# 1.75v12.5a1.75: 6
# 1.458: 6
# 0-.25-.25z"></path>: 6
# 11: 6
# d="m1.75: 6
# class="d-block: 6
# mb-3">: 6
# 4.499: 6
# 4.25: 6
# 1-1.275-.326.749.749: 6
# .326-1.275.749.749: 6
# 0-1: 6
# 0a8: 6
# 16a8: 6
# 0zm1.5: 6
# .784.784: 6
# 2.75: 6
# 2.559a.25.25: 6
# d="m3.72: 6
# 3.72a.75.75: 6
# 0l8: 6
# 6.94l3.22-3.22a.749.749: 6
# 1.275.326.749.749: 6
# 1-.215.734l9.06: 6
# 8l3.22: 6
# 3.22a.749.749: 6
# 1-.734-.215l8: 6
# 9.06l-3.22: 6
# 3.22a.751.751: 6
# 1-.018-1.042l6.94: 6
# 3.72: 6
# 4.78a.75.75: 6
# d="m5: 6
# aria-label="you: 6
# 3.25a2.25: 6
# 0v5.372a2.25: 6
# class="d-inline-flex">: 6
# data-analytics-event="{&quot;category&quot;:&quot;underline: 6
# navbar&quot;,&quot;action&quot;:&quot;click: 6
# class="underlinenav-item: 6
# js-responsive-underlinenav-item: 6
# underlinenav-octicon: 6
# d-sm-inline">: 6
# data-targets="action-list.items": 6
# role="none": 6
# class="actionlistitem">: 6
# role="menuitem": 6
# class="actionlistcontent: 6
# actionlistcontent--visual16">: 6
# class="actionlistitem-visual: 6
# actionlistitem-visual--leading">: 6
# class="actionlistitem-label">: 6
# </span></a>: 6
# 12px;gap:8px;min-width:-webkit-max-content;min-width:-moz-max-content;min-width:max-content;-webkit-transition:80ms: 6
# cubic-bezier(0.65,0,0.35,1);transition:80ms: 6
# [data-component=buttoncounter]{color:inherit;}/*!sc*/: 6
# transparent;}}/*!sc*/: 6
# 8px;height:28px;gap:4px;font-size:12px;}/*!sc*/: 6
# [data-component="text"]{line-height:calc(20: 6
# 12);}/*!sc*/: 6
# :not(:last-child){margin-right:4px;}/*!sc*/: 6
# 16px;height:40px;gap:8px;}/*!sc*/: 6
# [data-component="text"]{grid-area:text;line-height:calc(20/14);white-space:nowrap;}/*!sc*/: 6
# [data-component="trailingvisual"]{grid-area:trailingvisual;}/*!sc*/: 6
# [data-component="buttoncontent"]{-webkit-flex:1: 6
# auto;-ms-flex:1: 6
# auto;flex:1: 6
# auto;display:grid;grid-template-areas:"leadingvisual: 6
# text: 6
# trailingvisual";grid-template-columns:min-content: 6
# minmax(0,auto): 6
# min-content;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;}/*!sc*/: 6
# class="text-sc-17v1xeu-0: 6
# trpoq"><svg: 6
# class="react-directory-row: 6
# undefined": 6
# class="react-directory-row-name-cell-small-screen": 6
# colspan="2"><div: 6
# class="react-directory-row-name-cell-large-screen": 6
# colspan="1"><div: 6
# class="react-directory-row-commit-cell"><div: 6
# </div></td><td><div: 6
# </div></td></tr><tr: 6
# class="mt-2">: 6
# class="mx-2">: 6
# data-analytics-event="{&quot;category&quot;:&quot;footer&quot;,&quot;action&quot;:&quot;go: 6
# left-0: 5
# js-details-container: 5
# flex-column: 5
# px-3: 5
# d="m1: 5
# 1-1.75: 5
# 1.75v7.5a1.75: 5
# .25-.25v-7.5a.25.25: 5
# code: 5
# d="m1.5: 5
# 1.784.784: 5
# 0-.25-.25h1.75a.25.25: 5
# h4: 5
# my-1": 5
# source&quot;,&quot;action&quot;:&quot;click: 5
# 7.75: 5
# 8a6.5: 5
# 0-13: 5
# 16h1.75a1.75: 5
# 14: 5
# class="link: 5
# octicon-x">: 5
# data-csrf="true": 5
# your: 5
# class="link--intextblock": 5
# 0zm9: 5
# href="/login?return_to=%2fveroaba%2flabs": 5
# rel="nofollow": 5
# class="btn-sm: 5
# title="0": 5
# a: 5
# repository": 5
# mr-1">: 5
# data-hotkey="g: 5
# data-pjax-replace="": 5
# data-turbo-replace="": 5
# js-selected-navigation-item">: 5
# commit: 5
# data-component="leadingvisual": 5
# gpdewa: 5
# <h3: 5
# rel="dns-prefetch": 4
# type="application/json": 4
# content="contribute: 4
# veroaba/labs: 4
# development: 4
# by: 4
# creating: 4
# an: 4
# account: 4
# data-turbo-track="reload">: 4
# js-details-target": 4
# border: 4
# button--medium: 4
# class="headermenu-item: 4
# flex-lg-nowrap: 4
# flex-lg-items-center: 4
# js-header-menu-item">: 4
# px-0: 4
# px-lg-2: 4
# py-3: 4
# py-lg-2: 4
# m-0: 4
# 5.25: 4
# flex-items-center": 4
# 2.573a1.458: 4
# 1zm1.5: 4
# .75.75v2.19l2.72-2.72a.749.749: 4
# all: 4
# github: 4
# class="border-bottom: 4
# pb-3: 4
# class="">: 4
# readme: 4
# color-fg-muted">: 4
# class="overlay: 4
# <h1: 4
# data-view-component="true">: 4
# hidden: 4
# <label: 4
# class="sr-only": 4
# d="m11.28: 4
# 3.22: 4
# 4.25a.75.75: 4
# .215-.734l13.94: 4
# 8l-3.72-3.72a.749.749: 4
# .734.215zm-6.56: 4
# 0a.751.751: 4
# 1.042l2.06: 4
# 8l3.72: 4
# 3.72a.749.749: 4
# 1-.734-.215l.47: 4
# 8.53a.75.75: 4
# 1-.018: 4
# 1.042.751.751: 4
# 4.5: 4
# 0h12.5c15.216: 4
# .25-.25v1.75a.25.25: 4
# 1.75c0: 4
# 5a1: 4
# 1.042z"></path>: 4
# 9.64: 4
# 6.507: 4
# 2z"></path>: 4
# color-fg-muted: 4
# btn">: 4
# class="text-small: 4
# flex-shrink-0: 4
# popover="manual": 4
# data-direction="s": 4
# class="sr-only: 4
# data-turbo-replace>: 4
# <include-fragment: 4
# px-md-4: 4
# octicon-repo-forked: 4
# 5.372v.878c0: 4
# .414.336.75.75.75h4.5a.75.75: 4
# .75-.75v-.878a2.25: 4
# 0v.878a2.25: 4
# 1-2.25: 4
# 2.25h-1.5v2.128a2.251: 4
# 0v8.5h-1.5a2.25: 4
# 6.25v-.878a2.25: 4
# 0zm5: 4
# 0zm6.75.75a.75.75: 4
# 0-1.5.75.75: 4
# 1.5zm-3: 4
# 8.75a.75.75: 4
# change: 4
# notification: 4
# star: 4
# octicon-star: 4
# .25a.75.75: 4
# .673.418l1.882: 4
# 3.815: 4
# 4.21.612a.75.75: 4
# .416: 4
# 1.279l-3.046: 4
# 2.97.719: 4
# 4.192a.751.751: 4
# 1-1.088.791l8: 4
# 12.347l-3.766: 4
# 1.98a.75.75: 4
# 1-1.088-.79l.72-4.194l.818: 4
# 6.374a.75.75: 4
# .416-1.28l4.21-.611l7.327.668a.75.75: 4
# .25zm0: 4
# 2.445l6.615: 4
# 5.5a.75.75: 4
# 1-.564.41l-3.097.45: 4
# 2.24: 4
# 2.184a.75.75: 4
# .216.664l-.528: 4
# 3.084: 4
# 2.769-1.456a.75.75: 4
# .698: 4
# 0l2.77: 4
# 1.456-.53-3.084a.75.75: 4
# .216-.664l2.24-2.183-3.096-.45a.75.75: 4
# 1-.564-.41l8: 4
# 2.694z"></path>: 4
# d="m4.427: 4
# 7.427: 4
# 3.396: 4
# 3.396a.25.25: 4
# 0l3.396-3.396a.25.25: 4
# 11.396: 4
# 7h4.604a.25.25: 4
# d="m9.5: 4
# 2.122v6a2.5: 4
# 8.5h6a1: 4
# 1v1.128a2.251: 4
# 0v1.836a2.493: 4
# 2.493: 4
# 7h4a1: 4
# 1-1v-.628a2.25: 4
# 3.25zm-6: 4
# 0zm8.25-.75a.75.75: 4
# 0-1.5zm4.25: 4
# 12a.75.75: 4
# aria-haspopup="true": 4
# 9a1.5: 4
# 4.95: 4
# .751.751: 4
# .018-1.042.751.751: 4
# 2.83: 4
# -->: 4
# style="--button-color:fg.muted": 4
# data-no-visuals="true": 4
# class="bordergrid-row">: 4
# class="bordergrid-cell">: 4
# link--muted">: 4
# .138.112.25.25.25h7.5a.25.25: 4
# data-pjax-transient="true"/><meta: 3
# github.": 3
# env-production: 3
# position-fixed: 3
# d-lg-none: 3
# flex-lg-row: 3
# data-ga-click="(logged: 3
# out): 3
# header,: 3
# 2.15: 3
# class="flex-1">: 3
# px-2: 3
# data-hydro-click="{&quot;event_type&quot;:&quot;authentication.click&quot;,&quot;payload&quot;:{&quot;location_in_page&quot;:&quot;site: 3
# header: 3
# menu&quot;,&quot;repository_id&quot;:null,&quot;auth_type&quot;:&quot;sign_up&quot;,&quot;originating_url&quot;:&quot;https://github.com/veroaba/labs&quot;,&quot;user_id&quot;:null}}": 3
# data-hydro-click-hmac="188d21535fbca794e229b6c62a29915ab0f76dd24b9ee0d15ecadae0df270914": 3
# class="headermenu-toggle-bar: 3
# <nav: 3
# mb-3: 3
# width-lg-auto: 3
# aria-expanded="false">: 3
# opacity="0.5": 3
# octicon-chevron-down: 3
# headermenu-icon: 3
# ml-1">: 3
# d="m12.78: 3
# 5.22a.749.749: 3
# 0l3.22: 3
# 6.28a.749.749: 3
# 1.06-1.06l8: 3
# 8.939l3.72-3.719a.749.749: 3
# class="headermenu-dropdown: 3
# dropdown-menu: 3
# py-lg-4: 3
# position-lg-absolute: 3
# left-lg-n3: 3
# 5.5: 3
# manage: 3
# packages: 3
# 2.5a.75.75: 3
# .25-.25v-4a.25.25: 3
# 1.047c.659-1.234: 3
# 2.427-1.234: 3
# 3.086: 3
# 0l6.082: 3
# 11.378a1.75: 3
# 14.082: 3
# 15h1.918a1.75: 3
# 1-1.543-2.575zm1.763.707a.25.25: 3
# 0-.44: 3
# 0l1.698: 3
# 13.132a.25.25: 3
# .22.368h12.164a.25.25: 3
# .22-.368zm.53: 3
# 3.996v2.5a.75.75: 3
# 0v-2.5a.75.75: 3
# 11a1: 3
# hidden>you: 3
# another: 3
# tab: 3
# window.: 3
# href="">reload</a>: 3
# refresh: 3
# session.</span>: 3
# 2px: 3
# button&quot;,&quot;repository_id&quot;:797602071,&quot;auth_type&quot;:&quot;log_in&quot;,&quot;originating_url&quot;:&quot;https://github.com/veroaba/labs&quot;,&quot;user_id&quot;:null}}": 3
# class="counter">0</span>: 3
# class="d-inline">: 3
# starred: 3
# repository: 3
# d-inline-block": 3
# 7.775v2.75c1: 3
# 1h5.025c.464: 3
# .91.184: 3
# 1.238.513l6.25: 3
# 6.25a1.75: 3
# 2.474l-5.026: 3
# 5.026a1.75: 3
# 1-2.474: 3
# 0l-6.25-6.25a1.752: 3
# 1.752: 3
# 7.775zm1.5: 3
# 0c0: 3
# .066.026.13.073.177l6.25: 3
# 6.25a.25.25: 3
# 0l5.025-5.025a.25.25: 3
# 0-.354l-6.25-6.25a.25.25: 3
# 0-.177-.073h2.75a.25.25: 3
# 0-.25.25zm6: 3
# title="not: 3
# available": 3
# class="counter"></span>: 3
# position-absolute: 3
# .fruydv[data-size="small"]: 3
# [data-component="leadingvisual"]{grid-area:leadingvisual;}/*!sc*/: 3
# [data-component="trailingaction"]{margin-right:-4px;}/*!sc*/: 3
# solid;border-color:transparent;font-family:inherit;font-weight:500;font-size:14px;cursor:pointer;-webkit-appearance:none;-moz-appearance:none;appearance:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;text-align:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;height:32px;padding:0: 3
# [data-component="trailingaction"]{color:inherit;}/*!sc*/: 3
# .cuowtr[data-size="small"]: 3
# [data-component="leadingvisual"]{grid-area:leadingvisual;color:var(--fgcolor-muted,var(--color-fg-muted,#656d76));}/*!sc*/: 3
# [data-component="trailingaction"]{margin-right:-4px;color:var(--fgcolor-muted,var(--color-fg-muted,#656d76));}/*!sc*/: 3
# .tdszd[data-size="small"]: 3
# .pyyxt[data-size="small"]: 3
# .gyvpxq[data-size="small"]: 3
# .fakxqn[data-size="small"]: 3
# tabindex="0": 3
# octicon-git-branch": 3
# hidden="": 3
# class="heading__styledheading-sc-1c1dgg0-0: 3
# cgqnms: 3
# sr-only": 3
# <strong>0</strong>: 3
# class="h4: 3
# flex-justify-center: 3
# href="https://avatars.githubusercontent.com">: 2
# rel="preconnect": 2
# data-turbo-transient="true": 2
# title="github">: 2
# content="https://opengraph.githubassets.com/c98dda07e5eadd164fad99d5a70191323a99f80dcbcdc6f705a714004863fcbc/veroaba/labs": 2
# content="github: 2
# veroaba/labs": 2
# content="github.com">: 2
# content="true": 2
# content="779334857": 2
# content="hult-sci1-rahul/labs": 2
# class="js-site-favicon": 2
# class="logged-out: 2
# page-responsive": 2
# style="word-wrap:: 2
# 1.75v3.5a1.75: 2
# 9.784: 2
# 0-.25.25v3.5c0: 2
# .138.112.25.25.25h3.5a.25.25: 2
# .25-.25v-3.5a.25.25: 2
# 2.25z"></path>: 2
# 1.75v8.5a1.75: 2
# 9.22: 2
# 0h8.5c13.216: 2
# 1.75v5.5a1.75: 2
# 6h.5a.75.75: 2
# 3h.5a.75.75: 2
# 9h.5a.75.75: 2
# 2.143: 2
# 22.055: 2
# 2.836: 2
# 1.802: 2
# 1.58: 2
# 20.58: 2
# 14.5: 2
# 4.75a.75.75: 2
# 0-2: 2
# octicon-play">: 2
# 11.25: 2
# 1.25: 2
# 5.72: 2
# text-small: 2
# <dialog-helper>: 2
# <dialog: 2
# data-action="close:qbsearch-input#handledialogclose: 2
# cancel:qbsearch-input#handledialogclose": 2
# overlay-whennarrow: 2
# overlay--size-medium: 2
# overlay--motion-scalefade">: 2
# class="overlay-headercontentwrap">: 2
# class="overlay-titlewrap">: 2
# class="overlay-title: 2
# feedback: 2
# </h1>: 2
# class="overlay-actionwrap">: 2
# data-close-dialog-id="feedback-dialog": 2
# aria-label="close": 2
# class="close-button: 2
# overlay-closebutton"><svg: 2
# </svg></button>: 2
# <scrollable-region: 2
# class="overlay-body">: 2
# data-turbo="false": 2
# method="post"><input: 2
# name="authenticity_token": 2
# class="form-control: 2
# email: 2
# address: 2
# so: 2
# i: 2
# can: 2
# mr-2": 2
# </scrollable-region>: 2
# class="overlay-footer: 2
# class="btn">: 2
# cancel: 2
# type="submit": 2
# class="btn-primary: 2
# </dialog></dialog-helper>: 2
# searches: 2
# more: 2
# data-target="custom-scopes.customscopesmodaldialogflash"></div>: 2
# class="form-group">: 2
# class="form-control": 2
# required: 2
# see: 2
# d-lg-inline-block: 2
# up: 2
# flash: 2
# flash-warn: 2
# flash-full: 2
# octicon-alert">: 2
# </button><tool-tip: 2
# data-type="label": 2
# class="flash: 2
# class="flash-close: 2
# aria-label="dismiss: 2
# data-hydro-click="{&quot;event_type&quot;:&quot;authentication.click&quot;,&quot;payload&quot;:{&quot;location_in_page&quot;:&quot;notification: 2
# subscription: 2
# watch&quot;,&quot;repository_id&quot;:null,&quot;auth_type&quot;:&quot;log_in&quot;,&quot;originating_url&quot;:&quot;https://github.com/veroaba/labs&quot;,&quot;user_id&quot;:null}}": 2
# data-hydro-click-hmac="48236f7bdf0adeb9cb96516e47748a07736f5fe74704478cabfc40abf7df95e1": 2
# settings": 2
# octicon-bell: 2
# 16a2: 2
# 1.985-1.75c.017-.137-.097-.25-.235-.25h-3.5c-.138: 2
# 0-.252.113-.235.25a2: 2
# 16zm3: 2
# 5a5: 2
# 0v2.947c0: 2
# .05.015.098.042.139l1.703: 2
# 2.555a1.519: 2
# 1.519: 2
# 13.482: 2
# 13h2.518a1.516: 2
# 1.516: 2
# 1-1.263-2.36l1.703-2.554a.255.255: 2
# 7.947zm5-3.5a3.5: 2
# 5v2.947c0: 2
# .346-.102.683-.294.97l-1.703: 2
# 2.556a.017.017: 2
# 0-.003.01l.001.006c0: 2
# .002.002.004.004.006l.006.004.007.001h10.964l.007-.001.006-.004.004-.006.001-.007a.017.017: 2
# 0-.003-.01l-1.703-2.554a1.745: 2
# 1.745: 2
# 1-.294-.97v5a3.5: 2
# 1.5z"></path>: 2
# </svg>notifications: 2
# <tool-tip: 2
# data-type="description": 2
# position-absolute">you: 2
# settings</tool-tip>: 2
# fork: 2
# data-turbo-replace="true": 2
# class="btngroup: 2
# d-flex">: 2
# data-hydro-click="{&quot;event_type&quot;:&quot;authentication.click&quot;,&quot;payload&quot;:{&quot;location_in_page&quot;:&quot
# 0l7: 2
# 7.06: 2
# 4.28: 2
# 9.78a.751.751: 2
# 1-.018-1.042l3.25-3.25a.75.75: 2
# 0l10: 2
# 7.94l4.72-4.72a.751.751: 2
# 3zm1.5: 2
# 3zm13: 2
# 0a1.5: 2
# actions: 2
# not: 2
# belong: 2
# </div></div>: 2
# entry-content: 2
# 3.275: 2
# 1.25-1.25a3.5: 2
# 4.95l-2.5: 2
# 2.5a3.5: 2
# 1-4.95: 2
# 1.042-.018: 2
# 0l2.5-2.5a2.002: 2
# 2.002: 2
# 0-2.83-2.83l-1.25: 2
# 1.25a.751.751: 2
# 1-.018-1.042zm-4.69: 2
# 9.64a1.998: 2
# 0l1.25-1.25a.751.751: 2
# 1.042l-1.25: 2
# 1.25a3.5: 2
# 1-4.95-4.95l2.5-2.5a3.5: 2
# 1-1.042.018: 2
# 0-2.83: 2
# 0l-2.5: 2
# 2.5a1.998: 2
# .overview-ref-selector: 2
# [data-a11y-link-underlines='true']: 2
# .link__styledlink-sc-14289xe-0[data-inline='true']{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/: 2
# 1.25rem): 2
# .vlmkz: 2
# .12s: 2
# var(--fgcolor-accent,var(--color-accent-fg,#0969da));}/*!sc*/: 2
# solid;border-color:var(--button-default-bordercolor-rest,var(--button-default-bordercolor-rest,var(--color-btn-border,rgba(31,35,40,0.15))));font-family:inherit;font-weight:500;font-size:14px;cursor:pointer;-webkit-appearance:none;-moz-appearance:none;appearance:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;text-align:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;height:32px;padding:0: 2
# cubic-bezier(0.65,0,0.35,1);-webkit-transition-property:color,fill,background-color,border-color;transition-property:color,fill,background-color,border-color;color:var(--button-default-fgcolor-rest,var(--color-btn-text,#24292f));background-color:var(--button-default-bgcolor-rest,var(--color-btn-bg,#f6f8fa));box-shadow:var(--button-default-shadow-resting,var(--color-btn-shadow,0: 2
# rgba(31,35,40,0.04))),var(--button-default-shadow-inset,var(--color-btn-inset-shadow,inset: 2
# rgba(255,255,255,0.25)));}/*!sc*/: 2
# [data-component=buttoncounter]{font-size:12px;background-color:var(--buttoncounter-default-bgcolor-rest,var(--color-btn-counter-bg,rgba(31,35,40,0.08)));}/*!sc*/: 2
# [data-component="trailingaction"]{color:var(--button-color,var(--fgcolor-muted,var(--color-fg-muted,#656d76)));}/*!sc*/: 2
# cubic-bezier(0.65,0,0.35,1);-webkit-transition-property:color,fill,background-color,border-color;transition-property:color,fill,background-color,border-color;color:var(--button-default-fgcolor-rest,var(--color-btn-text,#24292f));background-color:transparent;box-shadow:none;}/*!sc*/: 2
# 3px;}/*!sc*/: 2
# rgba(0,45,17,0.2)));}/*!sc*/: 2
# tooltip-appear{from{opacity:0;}to{opacity:1;}}/*!sc*/: 2
# octicon-triangle-down": 2
# href="/veroaba/labs/branches": 2
# cuowtr"><span: 2
# href="/veroaba/labs/tags": 2
# octicon-tag": 2
# aria-label="go: 2
# page": 2
# tdszd"><svg: 2
# </div><div: 2
# text-bold">name</span></th><th: 2
# colspan="1": 2
# title="last: 2
# class="truncate__styledtruncate-sc-23o1d2-0: 2
# dlionx: 2
# width-fit"><span: 2
js"></script>: 1
# src="https://github.githubassets.com/assets/vendors-node_modules_morphdom_dist_morphdom-esm_js-node_modules_github_memoize_dist_esm_index_js-8d7117d67c36.js"></script>: 1
# src="https://github.githubassets.com/assets/vendors-node_modules_github_turbo_dist_turbo_es2017-esm_js-1cea0f5eff45.js"></script>: 1
# src="https://github.githubassets.com/assets/vendors-node_modules_github_remote-form_dist_index_js-node_modules_delegated-events_dist_inde-893f9f-880ac2bbb719.js"></script>: 1
# src="https://github.githubassets.com/assets/vendors-node_modules_scroll-anchoring_dist_scroll-anchoring_esm_js-node_modules_github_hotkey-1a1d91-1bb71f3f93c2.js"></script>: 1
# src="https://github.githubassets.com/assets/vendors-node_modules_color-convert_index_js-94fdbf91204e.js"></script>: 1
# src="https://github.githubassets.com/assets/vendors-node_modules_primer_behaviors_dist_esm_dimensions_js-node_modules_github_jtml_lib_index_js-b1947a1d4855.js"></script>: 1
# src="https://github.githubassets.com/assets/vendors-node_modules_github_session-resume_dist_index_js-node_modules_primer_behaviors_dist_e-da6ec6-77ce2f267f4e.js"></script>: 1
# src="https://github.githubassets.com/assets/vendors-node_modules_github_quote-selection_dist_index_js-node_modules_github_textarea-autosi-9e0349-704599a61056.js"></script>: 1
# src="https://github.githubassets.com/assets/app_assets_modules_github_updatable-content_ts-4d91e80fb877.js"></script>: 1
# src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_task-list_ts-app_assets_modules_github_onfocus_ts-app_ass-421cec-d3af2356fb47.js"></script>: 1
# src="https://github.githubassets.com/assets/app_assets_modules_github_sticky-scroll-into-view_ts-72d6e7bfb28f.js"></script>: 1
# src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_ajax-error_ts-app_assets_modules_github_behaviors_include-467754-25aa4f5b0d26.js"></script>: 1
# src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_commenting_edit_ts-app_assets_modules_github_behaviors_ht-83c235-5276a3faf037.js"></script>: 1
# src="https://github.githubassets.com/assets/behaviors-b75fc2506ff4.js"></script>: 1
# src="https://github.githubassets.com/assets/vendors-node_modules_delegated-events_dist_index_js-node_modules_github_catalyst_lib_index_js-06ff531-2ea61fcc9a71.js"></script>: 1
# src="https://github.githubassets.com/assets/notifications-global-0409f6303340.js"></script>: 1
# src="https://github.githubassets.com/assets/vendors-node_modules_virtualized-list_es_index_js-node_modules_github_template-parts_lib_index_js-878844713bc9.js"></script>: 1
# src="https://github.githubassets.com/assets/vendors-node_modules_github_remote-form_dist_index_js-node_modules_delegated-events_dist_inde-e53a3f-cefa903dda50.js"></script>: 1
# src="https://github.githubassets.com/assets/app_assets_modules_github_ref-selector_ts-fa04da463305.js"></script>: 1
# src="https://github.githubassets.com/assets/codespaces-55807ca411a8.js"></script>: 1
# src="https://github.githubassets.com/assets/vendors-node_modules_github_filter-input-element_dist_index_js-node_modules_github_mini-throt-1f9a80-7411de83ebdb.js"></script>: 1
# src="https://github.githubassets.com/assets/vendors-node_modules_github_file-attachment-element_dist_index_js-node_modules_github_mini-th-9dbbd2-dba0157157f7.js"></script>: 1
# src="https://github.githubassets.com/assets/app_assets_modules_github_repositories_get-repo-element_ts-e21ae6671295.js"></script>: 1
# src="https://github.githubassets.com/assets/repositories-c130330dbed8.js"></script>: 1
# src="https://github.githubassets.com/assets/code-menu-67595c3a6d0c.js"></script>: 1
# <title>github: 1
# veroaba/labs</title>: 1
# name="route-pattern": 1
# content="/:user_id/:repository": 1
# name="route-controller": 1
# content="files": 1
# name="route-action": 1
# content="disambiguate": 1
# name="current-catalog-service-hash": 1
# content="82c569b93da5c18ed649ebd4c2c79437db4611a6a1373e805a3cb001c64130b7">: 1
# name="request-id": 1
# content="9d0f:2f9031:15e5f8b:1dded7b:66555c93": 1
# name="html-safe-nonce": 1
# content="50bf7166e6d52aec33c6498413d463cdefdb8afbd9d06646075d782d7bf16cd9": 1
# name="visitor-payload": 1
# content="eyjyzwzlcnjlcii6iiisinjlcxvlc3rfawqioii5rdbgojjgotazmtoxnuu1rjhcojfereven0i6njy1ntvdotmilcj2axnpdg9yx2lkijoinzi0nzm4mdu2mzq4mdyzmjq2nyisinjlz2lvbl9lzgdlijoiawfkiiwicmvnaw9ux3jlbmrlcii6imlhzcj9": 1
# name="visitor-hmac": 1
# content="a216678f077f47241113d2a3817cb395362db88d0e04abbb1a1afe7c78643675": 1
# data-pjax-transient="true"/>: 1
# name="hovercard-subject-tag": 1
# content="repository:797602071": 1
# name="github-keyboard-shortcuts": 1
# content="repository,copilot": 1
# name="selected-link": 1
# value="repo_source": 1
# rel="assets": 1
# href="https://github.githubassets.com/">: 1
# name="google-site-verification": 1
# content="apib7-x98h0j5cpqhwwsmm6dnu4gmodroqxlidzdx9i">: 1
# name="octolytics-url": 1
# content="https://collector.github.com/github/collect": 1
# name="analytics-location": 1
# content="/&lt;user-name&gt;/&lt;repo-name&gt;": 1
# name="user-login": 1
# content="">: 1
# name="viewport": 1
# content="width=device-width">: 1
# name="description": 1
# github.">: 1
# rel="search": 1
# type="application/opensearchdescription+xml": 1
# href="/opensearch.xml": 1
# rel="fluid-icon": 1
# href="https://github.com/fluidicon.png": 1
# property="fb:app_id": 1
# content="1401488693436528">: 1
# name="apple-itunes-app": 1
# content="app-id=1477376905,: 1
# app-argument=https://github.com/veroaba/labs": 1
# name="twitter:image:src": 1
# name="twitter:site": 1
# content="@github": 1
# name="twitter:card": 1
# content="summary_large_image": 1
# name="twitter:title": 1
# name="twitter:description": 1
# property="og:image": 1
# property="og:image:alt": 1
# property="og:image:width": 1
# content="1200": 1
# property="og:image:height": 1
# content="600": 1
# property="og:site_name": 1
# content="github": 1
# property="og:type": 1
# content="object": 1
# property="og:title": 1
# property="og:url": 1
# content="https://github.com/veroaba/labs": 1
# property="og:description": 1
# name="hostname": 1
# name="expected-hostname": 1
# http-equiv="x-pjax-version": 1
# content="f077450301c5d4628ab40b8540f25e4fcd179809459615ee088f8134722bad59": 1
# http-equiv="x-pjax-csp-version": 1
# content="38c639a245e1dd04786881fae1060fbd72d3ed419b2f0d38d6082dc9d67876c3": 1
# http-equiv="x-pjax-css-version": 1
# content="8297669360f26c55eaf368df3078812f654eff1244bb59f8c32594aa15b30b3d": 1
# http-equiv="x-pjax-js-version": 1
# content="e1d33a3d305363bded2ae017e2aadd06443679fefb7d7b92094fb9cb4baac76e": 1
# name="turbo-cache-control": 1
# content="no-preview": 1
# data-turbo-transient="">: 1
# data-hydrostats="publish">: 1
# name="go-import": 1
# content="github.com/veroaba/labs: 1
# git: 1
# https://github.com/veroaba/labs.git">: 1
# name="octolytics-dimension-user_id": 1
# content="163913831": 1
# name="octolytics-dimension-user_login": 1
# content="veroaba": 1
# name="octolytics-dimension-repository_id": 1
# content="797602071": 1
# name="octolytics-dimension-repository_nwo": 1
# content="veroaba/labs": 1
# name="octolytics-dimension-repository_public": 1
# name="octolytics-dimension-repository_is_fork": 1
# name="octolytics-dimension-repository_parent_id": 1
# name="octolytics-dimension-repository_parent_nwo": 1
# name="octolytics-dimension-repository_network_root_id": 1
# name="octolytics-dimension-repository_network_root_nwo": 1
# rel="canonical": 1
# href="https://github.com/veroaba/labs": 1
# name="turbo-body-classes": 1
# content="logged-out: 1
# page-responsive">: 1
# name="browser-stats-url": 1
# content="https://api.github.com/_private/browser/stats">: 1
# name="browser-errors-url": 1
# content="https://api.github.com/_private/browser/errors">: 1
# rel="mask-icon": 1
# href="https://github.githubassets.com/assets/pinned-octocat-093da3e6fa40.svg": 1
# color="#000000">: 1
# rel="alternate: 1
# icon": 1
# type="image/png": 1
# href="https://github.githubassets.com/favicons/favicon.png">: 1
# rel="icon": 1
# type="image/svg+xml": 1
# href="https://github.githubassets.com/favicons/favicon.svg">: 1
# name="theme-color": 1
# content="#1e2327">: 1
# name="color-scheme": 1
# content="light: 1
# dark": 1
# rel="manifest": 1
# href="/manifest.json": 1
# crossorigin="use-credentials">: 1
# </head>: 1
# <body: 1
# data-turbo-body: 1
# js-header-wrapper: 1
# ">: 1
# href="#start-of-content": 1
# data-skip-target-assigned="false": 1
# class="px-2: 1
# py-4: 1
# color-bg-accent-emphasis: 1
# color-fg-on-emphasis: 1
# show-on-focus: 1
# js-skip-to-content">skip: 1
# content</a>: 1
# class="progress-pjax-loader: 1
# progress: 1
# width-full">: 1
# style="width:: 1
# 0%;": 1
# progress-pjax-loader-bar: 1
# color-bg-accent-emphasis"></span>: 1
# src="https://github.githubassets.com/assets/vendors-node_modules_primer_react_lib-esm_button_iconbutton_js-node_modules_primer_react_lib--1cd808-6070bc6b2c67.js"></script>: 1
# src="https://github.githubassets.com/assets/keyboard-shortcuts-dialog-52a107eb77ae.js"></script>: 1
# partial-name="keyboard-shortcuts-dialog": 1
# data-ssr="false": 1
# data-target="react-partial.embeddeddata">{"props":{"docsurl":"https://docs.github.com/get-started/accessibility/keyboard-shortcuts"}}</script>: 1
# data-target="react-partial.reactroot"></div>: 1
# src="https://github.githubassets.com/assets/vendors-node_modules_github_remote-form_dist_index_js-node_modules_delegated-events_dist_inde-94fd67-8743f7dc256e.js"></script>: 1
# src="https://github.githubassets.com/assets/sessions-458fee042571.js"></script>: 1
# <header: 1
# class="header-old: 1
# header-logged-out: 1
# f4: 1
# py-3": 1
# role="banner": 1
# data-color-mode=light: 1
# data-light-theme=light: 1
# data-dark-theme=dark>: 1
# class="sr-only">navigation: 1
# menu</h2>: 1
# class="header-backdrop: 1
# navigation">: 1
# class="d-none">toggle: 1
# navigation</span>: 1
# z-1">: 1
# width-lg-auto">: 1
# class="mr-lg-3: 1
# flex-order-2": 1
# href="https://github.com/": 1
# homepage,: 1
# icon:logo-wordmark">: 1
# height="32": 1
# width="32": 1
# class="d-inline-block: 1
# flex-order-1: 1
# f5: 1
# rounded-2: 1
# py-1: 1
# color-fg-inherit": 1
# class="flex-1: 1
# flex-order-2: 1
# text-right">: 1
# navigation": 1
# class="js-details-target: 1
# button--link: 1
# button: 1
# p-1">: 1
# class="button-content">: 1
# class="button-label"><div: 1
# my-1"></div></span>: 1
# class="headermenu--logged-out: 1
# height-fit: 1
# position-lg-relative: 1
# pt-7: 1
# pb-4: 1
# class="header-menu-wrapper: 1
# flex-self-end: 1
# p-3: 1
# p-lg-0: 1
# mt-3: 1
# mt-lg-0">: 1
# px-lg-0: 1
# aria-label="global">: 1
# product: 1
# dropdown-menu-wide">: 1
# class="px-lg-4: 1
# border-lg-right: 1
# mb-4: 1
# pr-lg-7">: 1
# actions&quot;,&quot;label&quot;:&quot;ref_cta:actions;&quot;}": 1
# href="https://github.com/features/actions">: 1
# octicon-workflow: 1
# 3a2: 1
# 2-2h6.5a2: 1
# 2v6.5a2: 1
# 2h7v4.063c7: 1
# 16.355: 1
# 7.644: 1
# 17: 1
# 8.438: 1
# 17h12.5v-2.5a2: 1
# 2-2h21a2: 1
# 2v21a2: 1
# 2h-6.5a2: 1
# 1-2-2v-2.5h8.437a2.939: 1
# 2.939: 1
# 15.562v11.5h3a2: 1
# 1-2-2zm2-.5a.5.5: 1
# 0-.5.5v6.5a.5.5: 1
# .5.5h6.5a.5.5: 1
# .5-.5v3a.5.5: 1
# 0-.5-.5zm14.5: 1
# 14a.5.5: 1
# 0-.5.5v21a.5.5: 1
# .5.5h21a.5.5: 1
# .5-.5v-6.5a.5.5: 1
# 0-.5-.5z"></path>: 1
# h4">actions</div>: 1
# automate: 1
# workflow: 1
# packages&quot;,&quot;label&quot;:&quot;ref_cta:packages;&quot;}": 1
# href="https://github.com/features/packages">: 1
# octicon-package: 1
# d="m12.876.64v.639l8.25: 1
# 4.763c.541.313.875.89.875: 1
# 1.515v9.525a1.75: 1
# 1-.875: 1
# 1.516l-8.25: 1
# 4.762a1.748: 1
# 0l-8.25-4.763a1.75: 1
# 1-.875-1.515v6.917c0-.625.334-1.202.875-1.515l11.126.64a1.748: 1
# 0zm-1: 1
# 1.298l4.251: 1
# 6.34l7.75: 1
# 4.474: 1
# 7.75-4.474-7.625-4.402a.248.248: 1
# 0zm.875: 1
# 19.123: 1
# 7.625-4.402a.25.25: 1
# .125-.216v7.639l-7.75: 1
# 4.474zm3.501: 1
# 7.64v8.803c0: 1
# .09.048.172.125.216l7.625: 1
# 4.402v-8.947z"></path>: 1
# h4">packages</div>: 1
# host: 1
# security&quot;,&quot;label&quot;:&quot;ref_cta:security;&quot;}": 1
# href="https://github.com/features/security">: 1
# octicon-shield-check: 1
# d="m16.53: 1
# 9.78a.75.75: 1
# 0-1.06-1.06l11: 1
# 13.19l-1.97-1.97a.75.75: 1
# 0-1.06: 1
# 1.06l2.5: 1
# 0l5-5z"></path><path: 1
# d="m12.54.637: 1
# 8.25: 1
# 2.675a1.75: 1
# 22: 1
# 4.976v10c0: 1
# 6.19-3.771: 1
# 10.704-9.401: 1
# 12.83a1.704: 1
# 1.704: 1
# 1-1.198: 1
# 0c5.77: 1
# 20.705: 1
# 16.19: 1
# 10v4.976c0-.758.489-1.43: 1
# 1.21-1.664l11.46.637a1.748: 1
# 1.08: 1
# 0zm-.617: 1
# 1.426-8.25: 1
# 2.676a.249.249: 1
# 0-.173.237v10c0: 1
# 5.46: 1
# 3.28: 1
# 9.483: 1
# 8.43: 1
# 11.426a.199.199: 1
# .14: 1
# 0c17.22: 1
# 19.483: 1
# 15.461: 1
# 10v4.976a.25.25: 1
# 0-.173-.237l-8.25-2.676a.253.253: 1
# 0-.154: 1
# h4">security</div>: 1
# find: 1
# fix: 1
# vulnerabilities: 1
# codespaces&quot;,&quot;label&quot;:&quot;ref_cta:codespaces;&quot;}": 1
# href="https://github.com/features/codespaces">: 1
# octicon-codespaces: 1
# d="m3.5: 1
# 3.75c3.5: 1
# 4.284: 1
# 2h13.5c.966: 1
# 18.75: 1
# 13h5.25a1.75: 1
# 1-1.75-1.75zm-2: 1
# 12c0-.966.784-1.75: 1
# 1.75v4a1.75: 1
# 1.75h3.25a1.75: 1
# 1-1.75-1.75zm5.25: 1
# 3.5a.25.25: 1
# .138.112.25.25.25h13.5a.25.25: 1
# 12a.25.25: 1
# .138.112.25.25.25h17.5a.25.25: 1
# d="m10: 1
# 17.75a.75.75: 1
# .75-.75h6.5a.75.75: 1
# 1.5h-6.5a.75.75: 1
# 1.02-1.1l3.5: 1
# 1.1l-3.5: 1
# 1-1.02-1.1l2.908-2.7-2.908-2.7z"></path><path: 1
# 4.25c0-.966.784-1.75: 1
# 1.75h-9.69l-3.573: 1
# 3.573a1.458: 1
# 21.043v18.5h3.25a1.75: 1
# 1-1.75-1.75zm3.25: 1
# 4a.25.25: 1
# .138.112.25.25.25h2.5a.75.75: 1
# .75.75v3.19l3.72-3.72a.749.749: 1
# .53-.22h10a.25.25: 1
# .25-.25v4.25a.25.25: 1
# h4">code: 1
# review</div>: 1
# changes: 1
# issues&quot;,&quot;label&quot;:&quot;ref_cta:issues;&quot;}": 1
# href="https://github.com/features/issues">: 1
# octicon-issue-opened: 1
# d="m12: 1
# 1c6.075: 1
# 4.925: 1
# 11s-4.925: 1
# 11-11: 1
# 11s1: 1
# 18.075: 1
# 5.925: 1
# 1zm2.5: 1
# 12a9.5: 1
# 9.5-9.5a9.5: 1
# 12zm9.5: 1
# 2a2: 1
# 14z"></path>: 1
# h4">issues</div>: 1
# plan: 1
# track: 1
# work: 1
# discussions&quot;,&quot;label&quot;:&quot;ref_cta:discussions;&quot;}": 1
# href="https://github.com/features/discussions">: 1
# ...
# .fakxqn:active:not([disabled]){background-color:var(--control-transparent-bgcolor-active,var(--color-action-list-item-default-active-bg,rgba(208,215,222,0.48)));-webkit-text-decoration:none;text-decoration:none;}/*!sc*/: 1
# .fakxqn[aria-expanded=true]{background-color:var(--control-transparent-bgcolor-selected,var(--color-action-list-item-default-selected-bg,rgba(208,215,222,0.24)));}/*!sc*/: 1
# .fakxqn[data-component="iconbutton"][data-no-visuals]{color:var(--fgcolor-muted,var(--color-fg-muted,#656d76));}/*!sc*/: 1
# .fakxqn[data-no-visuals]{color:var(--fgcolor-accent,var(--color-accent-fg,#0969da));}/*!sc*/: 1
# .fakxqn:has([data-component="buttoncounter"]){color:var(--button-default-fgcolor-rest,var(--color-btn-text,#24292f));}/*!sc*/: 1
# .fakxqn:disabled[data-no-visuals]{color:var(--fgcolor-disabled,var(--color-primer-fg-disabled,#8c959f));}/*!sc*/: 1
# .fakxqn:disabled[data-no-visuals]: 1
# .fakxqn:focus:not([disabled]){-webkit-text-decoration:none;text-decoration:none;}/*!sc*/: 1
# data-styled.g9[id="types__styledbutton-sc-ws60qy-0"]{content:"fruydv,cuowtr,tdszd,pyyxt,gyvpxq,fakxqn,"}/*!sc*/: 1
# .rtzss{position:absolute;width:1px;height:1px;padding:0;margin:-1px;overflow:hidden;-webkit-clip:rect(0,0,0,0);clip:rect(0,0,0,0);white-space:nowrap;border-width:0;}/*!sc*/: 1
# data-styled.g10[id="_visuallyhidden__visuallyhidden-sc-11jhm7a-0"]{content:"rtzss,"}/*!sc*/: 1
# .gngnvl{position:relative;display:inline-block;}/*!sc*/: 1
# .gngnvl::after{position:absolute;z-index:1000000;display:none;padding:0.5em: 1
# 0.75em;font:normal: 1
# normal: 1
# 11px/1.5: 1
# -apple-system,blinkmacsystemfont,"segoe: 1
# ui","noto: 1
# sans",helvetica,arial,sans-serif,"apple: 1
# color: 1
# emoji","segoe: 1
# ui: 1
# emoji";-webkit-font-smoothing:subpixel-antialiased;color:var(--fgcolor-onemphasis,var(--color-fg-on-emphasis,#ffffff));text-align:center;-webkit-text-decoration:none;text-decoration:none;text-shadow:none;text-transform:none;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;word-wrap:break-word;white-space:pre;pointer-events:none;content:attr(aria-label);background:var(--bgcolor-emphasis,var(--color-neutral-emphasis-plus,#24292f));border-radius:6px;opacity:0;}/*!sc*/: 1
# @-webkit-keyframes: 1
# @keyframes: 1
# .gngnvl:hover::after,.gngnvl:active::after,.gngnvl:focus::after,.gngnvl:focus-within::after{display:inline-block;-webkit-text-decoration:none;text-decoration:none;-webkit-animation-name:tooltip-appear;animation-name:tooltip-appear;-webkit-animation-duration:0.1s;animation-duration:0.1s;-webkit-animation-fill-mode:forwards;animation-fill-mode:forwards;-webkit-animation-timing-function:ease-in;animation-timing-function:ease-in;-webkit-animation-delay:0s;animation-delay:0s;}/*!sc*/: 1
# .gngnvl.tooltipped-no-delay:hover::after,.gngnvl.tooltipped-no-delay:active::after,.gngnvl.tooltipped-no-delay:focus::after,.gngnvl.tooltipped-no-delay:focus-within::after{-webkit-animation-delay:0s;animation-delay:0s;}/*!sc*/: 1
# .gngnvl.tooltipped-multiline:hover::after,.gngnvl.tooltipped-multiline:active::after,.gngnvl.tooltipped-multiline:focus::after,.gngnvl.tooltipped-multiline:focus-within::after{display:table-cell;}/*!sc*/: 1
# .gngnvl.tooltipped-s::after,.gngnvl.tooltipped-se::after,.gngnvl.tooltipped-sw::after{top:100%;right:50%;margin-top:6px;}/*!sc*/: 1
# .gngnvl.tooltipped-se::after{right:auto;left:50%;margin-left:-16px;}/*!sc*/: 1
# .gngnvl.tooltipped-sw::after{margin-right:-16px;}/*!sc*/: 1
# .gngnvl.tooltipped-n::after,.gngnvl.tooltipped-ne::after,.gngnvl.tooltipped-nw::after{right:50%;bottom:100%;margin-bottom:6px;}/*!sc*/: 1
# .gngnvl.tooltipped-ne::after{right:auto;left:50%;margin-left:-16px;}/*!sc*/: 1
# .gngnvl.tooltipped-nw::after{margin-right:-16px;}/*!sc*/: 1
# .gngnvl.tooltipped-s::after,.gngnvl.tooltipped-n::after{-webkit-transform:translatex(50%);-ms-transform:translatex(50%);transform:translatex(50%);}/*!sc*/: 1
# .gngnvl.tooltipped-w::after{right:100%;bottom:50%;margin-right:6px;-webkit-transform:translatey(50%);-ms-transform:translatey(50%);transform:translatey(50%);}/*!sc*/: 1
# .gngnvl.tooltipped-e::after{bottom:50%;left:100%;margin-left:6px;-webkit-transform:translatey(50%);-ms-transform:translatey(50%);transform:translatey(50%);}/*!sc*/: 1
# .gngnvl.tooltipped-multiline::after{width:-webkit-max-content;width:-moz-max-content;width:max-content;max-width:250px;word-wrap:break-word;white-space:pre-line;border-collapse:separate;}/*!sc*/: 1
# .gngnvl.tooltipped-multiline.tooltipped-s::after,.gngnvl.tooltipped-multiline.tooltipped-n::after{right:auto;left:50%;-webkit-transform:translatex(-50%);-ms-transform:translatex(-50%);transform:translatex(-50%);}/*!sc*/: 1
# .gngnvl.tooltipped-multiline.tooltipped-w::after,.gngnvl.tooltipped-multiline.tooltipped-e::after{right:100%;}/*!sc*/: 1
# .gngnvl.tooltipped-align-right-2::after{right:0;margin-right:0;}/*!sc*/: 1
# .gngnvl.tooltipped-align-left-2::after{left:0;margin-left:0;}/*!sc*/: 1
# data-styled.g14[id="tooltip__tooltipbase-sc-17tf59c-0"]{content:"gngnvl,"}/*!sc*/: 1
# .dlionx{display:inline-block;overflow:hidden;text-overflow:ellipsis;vertical-align:top;white-space:nowrap;max-width:125px;}/*!sc*/: 1
# data-styled.g16[id="truncate__styledtruncate-sc-23o1d2-0"]{content:"dlionx,"}/*!sc*/: 1
# .bpgibo{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;list-style:none;white-space:nowrap;padding-top:0;padding-bottom:0;padding-left:0;padding-right:0;margin:0;margin-bottom:-1px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;gap:8px;position:relative;}/*!sc*/: 1
# data-styled.g103[id="underlinenav__navigationlist-sc-1jfr31k-0"]{content:"bpgibo,"}/*!sc*/: 1
# </style>: 1
# izjvbm"><div: 1
# rpqgy"><div: 1
# eumedg"></div></div><div: 1
# elcvee"><div: 1
# hsfllq"><div: 1
# gpkouz"><button: 1
# id="branch-picker-repos-header-ref-selector": 1
# aria-label="main: 1
# branch": 1
# data-testid="anchor-button": 1
# fruydv: 1
# overview-ref-selector: 1
# width-full"><span: 1
# data-component="text"><div: 1
# bkgizp"><div: 1
# ipgysi"><svg: 1
# 0-1.5z"></path></svg></div><div: 1
# caeydk: 1
# ref-selector-button-text-container"><span: 1
# bomzpg">: 1
# -->main</span></div></div></span><span: 1
# data-component="trailingvisual": 1
# 0-.177.427z"></path></svg></span></span></button><button: 1
# data-hotkey-scope="read-only-cursor-text-area"></button></div><div: 1
# layubz"><a: 1
# 0-1.5z"></path></svg></span><span: 1
# data-component="text">branches</span></span></a><a: 1
# 0-2z"></path></svg></span><span: 1
# data-component="text">tags</span></span></a></div><div: 1
# swnal"><a: 1
# branches: 1
# 0-1.5z"></path></svg></a><a: 1
# tags: 1
# 0-2z"></path></svg></a></div></div><div: 1
# bwpubf"><div: 1
# grhjnb"><div: 1
# dxtsqj"><!--$!--><template></template><!--/$--></div><div: 1
# dcormu"><button: 1
# pyyxt"><span: 1
# data-component="text">go: 1
# file</span></span></button></div><div: 1
# class="react-directory-add-file-icon"></div><div: 1
# class="react-directory-remove-file-icon"></div></div><button: 1
# id=":r55ab:": 1
# gyvpxq"><span: 1
# trpoq"><div: 1
# bvvbgp"><svg: 1
# octicon-code": 1
# 0-1.06z"></path></svg></div></span><span: 1
# data-component="text">code</span></span><span: 1
# data-component="trailingaction": 1
# 0-.177.427z"></path></svg></span></button><div: 1
# bndvfp"><button: 1
# data-component="iconbutton": 1
# aria-label="open: 1
# menu": 1
# id=":r75ab:": 1
# pyyxt"><svg: 1
# octicon-kebab-horizontal": 1
# 3z"></path></svg></button></div></div></div><div: 1
# data-testid="branch-info-bar": 1
# bgmdew"><div: 1
# style="width:40%": 1
# style="width:30%": 1
# </div></div><div: 1
# yfpnm"><div: 1
# data-hpc="true": 1
# class="box-sc-g0xbh4-0"><button: 1
# data-testid="focus-next-element-button": 1
# data-hotkey="j"></button><button: 1
# data-testid="focus-previous-element-button": 1
# data-hotkey="k"></button><h2: 1
# data-testid="screen-reader-heading": 1
# id="folders-and-files">folders: 1
# files</h2><table: 1
# aria-labelledby="folders-and-files": 1
# caquiw"><thead: 1
# iiulln"><tr: 1
# jmggsn"><th: 1
# colspan="2": 1
# kvyunm"><span: 1
# hrluxa"><span: 1
# epjhha"><div: 1
# message": 1
# message</span></div></th><th: 1
# cuekae"><div: 1
# date": 1
# date</span></div></th></tr></thead><tbody><tr: 1
# jebbot"><td: 1
# class="bgcolor-muted: 1
# p-1: 1
# rounded-top-2"><div: 1
# brjrqk"><h2: 1
# data-testid="screen-reader-heading">latest: 1
# commit</h2><div: 1
# style="width:120px": 1
# skeleton--text": 1
# data-testid="loading">: 1
# gap-2"><div: 1
# data-testid="latest-commit-details": 1
# class="d-none: 1
# d-sm-flex: 1
# flex-items-center"></div><div: 1
# gap-2"><h2: 1
# data-testid="screen-reader-heading">history</h2><a: 1
# fakxqn: 1
# d-lg-flex": 1
# 4z"></path></svg></span><span: 1
# data-component="text"><span: 1
# fgcolor-default">5: 1
# commits</span></span></span></a><div: 1
# bqgljk"></div><div: 1
# d-lg-none"><span: 1
# role="tooltip": 1
# aria-label="5: 1
# commits": 1
# id="history-icon-button-tooltip": 1
# class="tooltip__tooltipbase-sc-17tf59c-0: 1
# gngnvl: 1
# tooltipped-n"><a: 1
# aria-describedby="history-icon-button-tooltip": 1
# fakxqn": 1
# 4z"></path></svg></span></span></a></span></div></div></div></div></td></tr><tr: 1
# id="folder-row-0"><td: 1
# id="folder-row-1"><td: 1
# id="folder-row-2"><td: 1
# id="folder-row-3"><td: 1
# id="folder-row-4"><td: 1
# id="folder-row-5"><td: 1
# epsqed: 1
# d-none": 1
# data-testid="view-all-files-row"><td: 1
# ldpruc"><div><button: 1
# dheqrw">view: 1
# files</button></div></td></tr></tbody></table></div><div: 1
# ehcssh"><div: 1
# igmlub"><div: 1
# irqgxa"><h2: 1
# class="_visuallyhidden__visuallyhidden-sc-11jhm7a-0: 1
# rtzss">repository: 1
# files: 1
# navigation</h2><nav: 1
# aria-label="repository: 1
# files": 1
# dvtdpk"><ul: 1
# role="list": 1
# class="underlinenav__navigationlist-sc-1jfr31k-0: 1
# bpgibo"><li: 1
# gwuigu"><a: 1
# href="#": 1
# vlmkz"><span: 1
# data-component="icon": 1
# koxwqs"><svg: 1
# octicon-book": 1
# 2.25z"></path></svg></span><span: 1
# data-component="text": 1
# data-content="readme": 1
# kogefj">readme</span></a></li></ul></nav></div><div: 1
# bjmelz: 1
# js-snippet-clipboard-copy-unpositioned": 1
# data-hpc="true"><article: 1
# class="markdown-body: 1
# container-lg": 1
# itemprop="text"><div: 1
# class="markdown-heading": 1
# dir="auto"><h1: 1
# class="heading-element": 1
# dir="auto">labs</h1><a: 1
# id="user-content-labs": 1
# class="anchor": 1
# aria-label="permalink:: 1
# labs": 1
# href="#labs"><svg: 1
# octicon-link": 1
# aria-hidden="true"><path: 1
# d="m7.775: 1
# 2.83z"></path></svg></a></div>: 1
# </article></div></div></div></div></div>: 1
# id="__primer_data_:r0:__">{"resolvedservercolormode":"day"}</script></div>: 1
# value="gmiasnhln6x2gogomghbndyakrvfmvkgkhpkqs6olewa1e8wfzitrmh62niqt5dugcvq0csqsihqqztpdatfpg==": 1
# class="layout-sidebar">: 1
# class="bordergrid: 1
# about-margin": 1
# data-pjax>: 1
# class="hide-sm: 1
# hide-md">: 1
# class="mb-3: 1
# h4">about</h2>: 1
# class="f4: 1
# my-3: 1
# text-italic">: 1
# description,: 1
# website,: 1
# provided.: 1
# class="sr-only">resources</h3>: 1
# data-analytics-event="{&quot;category&quot;:&quot;repository: 1
# overview&quot;,&quot;action&quot;:&quot;click&quot;,&quot;label&quot;:&quot;location:sidebar;file:readme&quot;}": 1
# href="#readme-ov-file">: 1
# octicon-book: 1
# src="/veroaba/labs/hovercards/citation/sidebar_partial?tree_name=main">: 1
# </include-fragment>: 1
# href="/veroaba/labs/activity": 1
# text="gray": 1
# class="color-fg-muted">activity</span>: 1
# class="sr-only">stars</h3>: 1
# href="/veroaba/labs/stargazers": 1
# class="sr-only">watchers</h3>: 1
# href="/veroaba/labs/watchers": 1
# octicon-eye: 1
# 2c1.981: 1
# 3.671.992: 1
# 4.933: 1
# 2.078: 1
# 1.27: 1
# 1.091: 1
# 2.187: 1
# 2.345: 1
# 2.637: 1
# 3.023a1.62: 1
# 1.798c-.45.678-1.367: 1
# 1.932-2.637: 1
# 3.023c11.67: 1
# 13.008: 1
# 9.981: 1
# 14c-1.981: 1
# 0-3.671-.992-4.933-2.078c1.797: 1
# 10.83.88: 1
# 9.576.43: 1
# 8.898a1.62: 1
# 0-1.798c.45-.677: 1
# 1.367-1.931: 1
# 2.637-3.022c4.33: 1
# 2.992: 1
# 6.019: 1
# 2zm1.679: 1
# 7.932a.12.12: 1
# .136c.411.622: 1
# 1.241: 1
# 2.366: 1
# 2.717c5.176: 1
# 11.758: 1
# 6.527: 1
# 12.5: 1
# 12.5c1.473: 1
# 2.825-.742: 1
# 3.955-1.715: 1
# 1.124-.967: 1
# 1.954-2.096: 1
# 2.366-2.717a.12.12: 1
# 0-.136c-.412-.621-1.242-1.75-2.366-2.717c10.824: 1
# 4.242: 1
# 9.473: 1
# 3.5c-1.473: 1
# 0-2.825.742-3.955: 1
# 1.715-1.124.967-1.954: 1
# 2.096-2.366: 1
# 2.717zm8: 1
# 10a2: 1
# 10z"></path>: 1
# watching: 1
# class="sr-only">forks</h3>: 1
# href="/veroaba/labs/forks": 1
# href="/contact/report-content?content_url=https%3a%2f%2fgithub.com%2fveroaba%2flabs&amp;report=veroaba+%28user%29">: 1
# report: 1
# mb-3": 1
# data-turbo-frame="repo-content-turbo-frame">: 1
# href="/veroaba/labs/releases": 1
# link">: 1
# color-fg-muted">no: 1
# published</div>: 1
# href="/users/veroaba/packages?repo_name=labs": 1
# link: 1
# flex-items-center">: 1
# ml-1">0</span>: 1
# published: 1
# <br>: 1
# mb-3">languages</h2>: 1
# class="mb-2">: 1
# class="progress">: 1
# style="background-color:#da5b0b: 1
# !important;;width:: 1
# 100.0%;": 1
# itemprop="keywords": 1
# aria-label="jupyter: 1
# notebook: 1
# 100.0": 1
# color-bg-success-emphasis"></span>: 1
# </span></div>: 1
# class="list-style-none">: 1
# class="d-inline-flex: 1
# flex-nowrap: 1
# style="color:#da5b0b;": 1
# octicon-dot-fill: 1
# text-bold: 1
# mr-1">jupyter: 1
# notebook</span>: 1
# <span>100.0%</span>: 1
# </turbo-frame>: 1
# </main>: 1
# <footer: 1
# class="footer: 1
# pt-8: 1
# pb-6: 1
# f6: 1
# p-responsive": 1
# role="contentinfo": 1
# class='sr-only'>footer</h2>: 1
# flex-column-reverse: 1
# flex-lg-nowrap">: 1
# mx-2">: 1
# title="github": 1
# class="footer-octicon: 1
# href="https://github.com">: 1
# &copy;: 1
# 2024: 1
# github,&nbsp;inc.: 1
# aria-label="footer">: 1
# id="sr-footer-heading">footer: 1
# navigation</h3>: 1
# aria-labelledby="sr-footer-heading">: 1
# terms&quot;,&quot;label&quot;:&quot;text:terms&quot;}": 1
# href="https://docs.github.com/site-policy/github-terms/github-terms-of-service": 1
# link">terms</a>: 1
# privacy&quot;,&quot;label&quot;:&quot;text:privacy&quot;}": 1
# href="https://docs.github.com/site-policy/privacy-policies/github-privacy-statement": 1
# link">privacy</a>: 1
# security&quot;,&quot;label&quot;:&quot;text:security&quot;}": 1
# href="https://github.com/security": 1
# link">security</a>: 1
# status&quot;,&quot;label&quot;:&quot;text:status&quot;}": 1
# href="https://www.githubstatus.com/": 1
# link">status</a>: 1
# docs&quot;,&quot;label&quot;:&quot;text:docs&quot;}": 1
# href="https://docs.github.com/": 1
# link">docs</a>: 1
# contact&quot;,&quot;label&quot;:&quot;text:contact&quot;}": 1
# href="https://support.github.com?tags=dotcom-footer": 1
# link">contact</a>: 1
# class="mr-3": 1
# cookies: 1
# class="mr-3">: 1
# do: 1
# share: 1
# personal: 1
# information: 1
# </footer>: 1
# <ghcc-consent: 1
# id="ghcc": 1
# class="position-fixed: 1
# bottom-0: 1
# left-0": 1
# style="z-index:: 1
# 999999": 1
# data-initial-cookie-consent-allowed="": 1
# data-cookie-consent-required="false"></ghcc-consent>: 1
# id="ajax-error-message": 1
# class="ajax-error-message: 1
# flash-error": 1
# hidden>: 1
# js-ajax-error-dismiss": 1
# error">: 1
# you: 1
# can’t: 1
# perform: 1
# that: 1
# action: 1
# at: 1
# time.: 1
# id="site-details-dialog">: 1
# <details: 1
# class="details-reset: 1
# details-overlay: 1
# details-overlay-dark: 1
# lh-default: 1
# hx_rsm": 1
# open>: 1
# <summary: 1
# dialog"></summary>: 1
# <details-dialog: 1
# class="box: 1
# box--overlay: 1
# anim-fade-in: 1
# fast: 1
# hx_rsm-dialog: 1
# hx_rsm-modal">: 1
# class="box-btn-octicon: 1
# btn-octicon: 1
# top-0": 1
# dialog": 1
# data-close-dialog>: 1
# class="octocat-spinner: 1
# my-6: 1
# js-details-dialog-spinner"></div>: 1
# </details-dialog>: 1
# </details>: 1
# class="popover: 1
# js-hovercard-content: 1
# position-absolute": 1
# style="display:: 1
# none;: 1
# outline:: 1
# none;": 1
# tabindex="0">: 1
# class="popover-message: 1
# popover-message--bottom-left: 1
# popover-message--large: 1
# box: 1
# color-shadow-large": 1
# style="width:360px;">: 1
# id="snippet-clipboard-copy-button">: 1
# class="zeroclipboard-container: 1
# tooltipped-no-delay": 1
# js-clipboard-copy-icon: 1
# id="snippet-clipboard-copy-button-unpositioned">: 1
# class="zeroclipboard-container">: 1
# btn-invisible: 1
# tooltipped-no-delay: 1
# js-clipboard-copy-icon">: 1
# d-none">: 1
# id="js-global-screen-reader-notice": 1
# id="js-global-screen-reader-notice-assertive": 1
# aria-live="assertive": 1
# aria-atomic="true"></div>: 1
# </body>: 1
# </html>: 1

# %%
import string

def read_and_count_words(file_path):
    word_count = {}
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            # Remove punctuation and convert to lowercase
            line = line.translate(str.maketrans('', '', string.punctuation)).lower()
            words = line.split()
            for word in words:
                if word in word_count:
                    word_count[word] += 1
                else:
                    word_count[word] = 1
    return word_count

def print_top_words(word_count, top_n=20):
    # Sort words by frequency in descending order
    sorted_words = sorted(word_count.items(), key=lambda x: x[1], reverse=True)
    for word, count in sorted_words[:top_n]:
        print(f"{word:20} {count}")

def print_histogram(word_count, top_n=20):
    sorted_words = sorted(word_count.items(), key=lambda x: x[1], reverse=True)
    for word, count in sorted_words[:top_n]:
        print(f"{word:20} {'#' * (count // 10)}")

# Specify the path to your text file
file_path = 'julius_caesar.text'

# Process the file
word_count = read_and_count_words(file_path)

# Print top words and their counts
print_top_words(word_count)

# Print a histogram
print_histogram(word_count)
# Out:
# the                  858
# and                  763
# of                   569
# to                   539
# i                    504
# you                  459
# a                    345
# brutus               324
# that                 313
# is                   298
# in                   294
# not                  287
# p                    256
# for                  242
# with                 216
# this                 213
# cassius              200
# it                   197
# caesar               189
# my                   189
# the                  #####################################################################################
# and                  ############################################################################
# of                   ########################################################
# to                   #####################################################
# i                    ##################################################
# you                  #############################################
# a                    ##################################
# brutus               ################################
# that                 ###############################
# is                   #############################
# in                   #############################
# not                  ############################
# p                    #########################
# for                  ########################
# with                 #####################
# this                 #####################
# cassius              ####################
# it                   ###################
# caesar               ##################
# my                   ##################

# %% [markdown]
# You can even make a hacky histogram for this by creating a '#' for every 10 occurences

# %% [markdown]
# Now here is where the iterative nature of dictionaries can be used to our benefit. We sort the worddict, using the function `worddict.get` to provide the values, which are the counts.

# %% [markdown]
# ## EXERCISE 2: Simulate a Bank Account

# %%
class BankAccount:
    def __init__(self, balance):
        self.balance = balance
        
    def withdraw(self, amount):
        self.balance = self.balance - amount

# %%
myaccount = BankAccount(100)
print(myaccount.balance)
myaccount.withdraw(20)
myaccount.balance
# Out:
# 100
# 80

# %% [markdown]
# Python supports inheritance. Indeed, in python, all classes inherit from object, which means that they all get some attributes and methods from object.
#
# What is inheritance, more precisely? In inheritance an object is based on another object. When inheritance is implemented, the methods and attributes that were defined in the base class will also be present in the inherited class. This is generally done to abstract away similar code in multiple classes. The abstracted code will reside in the base class and the previous classes will now inherit from the base class.
#
# Let's look at an example of inheritance. In the following example, Rocket is the base class and MarsRover is the inherited class. Notice the string interpolation in the formatting as well.

# %%
class Rocket:
    def __init__(self, name, distance):
        self.name = name
        self.distance = distance

    def launch(self):
        return "%s has reached %s" % (self.name, self.distance)
    
    def get_maker(self):
        return "%s Launched" % self.name


class MarsRover(Rocket): # inheriting from the base class
    def __init__(self, name, distance, maker):
        Rocket.__init__(self, name, distance)
        self.maker = maker

    def get_maker(self):
        return "%s Launched by %s" % (self.name, self.maker)

# %%
x = Rocket("Simple rocket", "till stratosphere")
y = MarsRover("Mangalyaan", "till Mars", "ISRO")
print(x.launch())
print(y.launch()) # dispatches to Ricket's launch
print(x.get_maker())
print(y.get_maker())
# Out:
# Simple rocket has reached till stratosphere
# Mangalyaan has reached till Mars
# Simple rocket Launched
# Mangalyaan Launched by ISRO

# %% [markdown]
# `launch` is not defined by the derived class `MarsRover` so the `launch` for instance `y` is used from `Rocket`. On the other hand, `MarsRover` defines a new `get_maker` so that overrides the one from `Rocket`. Thus inheritance can be used to share functionality when needed and diversify when not.

# %% [markdown]
# Define an error checking bank account `ECBankAccount` which inherits from `BankAccount` but will not allow overdraws. If there is an overdraw raise a `ValueError` with a message "Withdrawal Not Allowed": read up on this. Create two accounts one regular and one he derived class instance and wihdraw more than the balance from both.

# %%
# youe code here
class BankAccount:
    def __init__(self, balance):
        self.balance = balance

    def withdraw(self, amount):
        self.balance -= amount

class ECBankAccount(BankAccount):
    def withdraw(self, amount):
        if self.balance - amount < 0:
            raise ValueError("Withdrawal Not Allowed")
        self.balance -= amount

# Create instances of both the regular and error-checking bank accounts
regular_account = BankAccount(100)
ec_account = ECBankAccount(100)

# Test the regular account
print("Regular Account:")
print("Initial Balance:", regular_account.balance)
regular_account.withdraw(20)
print("After Withdrawal:", regular_account.balance)

# Test the error-checking account with a valid withdrawal
print("\nError-Checking Account:")
print("Initial Balance:", ec_account.balance)
ec_account.withdraw(20)
print("After Valid Withdrawal:", ec_account.balance)

# Test the error-checking account with an invalid withdrawal (overdraft attempt)
try:
    ec_account.withdraw(120)
except ValueError as e:
    print(str(e))
# Out:
# Regular Account:
# Initial Balance: 100
# After Withdrawal: 80
#
# Error-Checking Account:
# Initial Balance: 100
# After Valid Withdrawal: 80
# Withdrawal Not Allowed

# %%
x = BankAccount(100)
x.withdraw(120)
x.balance
# Out:
# -20

# %%
y = ECBankAccount(100)
y.withdraw(120)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 2
#       1 y = ECBankAccount(100)
# ----> 2 y.withdraw(120)
#
# Cell In[12], line 12, in ECBankAccount.withdraw(self, amount)
#      10 def withdraw(self, amount):
#      11     if self.balance - amount < 0:
# ---> 12         raise ValueError("Withdrawal Not Allowed")
#      13     self.balance -= amount
#
# ValueError: Withdrawal Not Allowed

# %%
y.balance
# Out:
# 100
